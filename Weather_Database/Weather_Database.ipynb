# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the random module.
import random

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 771

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f43227b91c3e432881f0cbb7d6aa0fa

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | colac
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | samarai
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | birjand
# Processing Record 7 of Set 1 | tutoia
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | sola
# Processing Record 10 of Set 1 | ilulissat
# Processing Record 11 of Set 1 | linping
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | goderich
# Processing Record 15 of Set 1 | zhanakorgan
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | makueni
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | khani
# Processing Record 20 of Set 1 | lorengau
# Processing Record 21 of Set 1 | bac lieu
# Processing Record 22 of Set 1 | ponta do sol
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | barcelos
# Processing Record 25 of Set 1 | arlit
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | chau doc
# Processing Record 31 of Set 1 | kununurra
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | mount isa
# Processing Record 34 of Set 1 | furmanov
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | namibe
# Processing Record 38 of Set 1 | oktyabrskoye
# Processing Record 39 of Set 1 | kollam
# Processing Record 40 of Set 1 | verkhnyaya inta
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 1 | pelym
# Processing Record 44 of Set 1 | yerbogachen
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | souillac
# Processing Record 47 of Set 1 | semey
# Processing Record 48 of Set 1 | rawlins
# Processing Record 49 of Set 1 | oromocto
# Processing Record 50 of Set 1 | khatanga
# Processing Record 1 of Set 2 | barsovo
# Processing Record 2 of Set 2 | meridian
# Processing Record 3 of Set 2 | saldanha
# Processing Record 4 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | tarauaca
# Processing Record 9 of Set 2 | yumen
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | saint-philippe
# Processing Record 12 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 2 | wadi maliz
# Processing Record 14 of Set 2 | scarborough
# Processing Record 15 of Set 2 | itarema
# Processing Record 16 of Set 2 | padang
# Processing Record 17 of Set 2 | belaya gora
# Processing Record 18 of Set 2 | tromso
# Processing Record 19 of Set 2 | zapolyarnyy
# Processing Record 20 of Set 2 | lompoc
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | san vicente
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | furstenwalde
# Processing Record 25 of Set 2 | redmond
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 2 | sangar
# Processing Record 30 of Set 2 | muroto
# Processing Record 31 of Set 2 | cidreira
# Processing Record 32 of Set 2 | lata
# Processing Record 33 of Set 2 | anloga
# Processing Record 34 of Set 2 | ribeira grande
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | geraldton
# Processing Record 37 of Set 2 | pangnirtung
# Processing Record 38 of Set 2 | mul
# Processing Record 39 of Set 2 | masterton
# Processing Record 40 of Set 2 | bethel
# Processing Record 41 of Set 2 | coahuayana
# Processing Record 42 of Set 2 | dunedin
# Processing Record 43 of Set 2 | beyneu
# Processing Record 44 of Set 2 | muisne
# Processing Record 45 of Set 2 | mayskiy
# Processing Record 46 of Set 2 | qaanaaq
# Processing Record 47 of Set 2 | lujan
# Processing Record 48 of Set 2 | borlange
# City not found. Skipping...
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | busselton
# Processing Record 1 of Set 3 | marzuq
# Processing Record 2 of Set 3 | nikolskoye
# Processing Record 3 of Set 3 | navlya
# Processing Record 4 of Set 3 | dali
# Processing Record 5 of Set 3 | hobart
# Processing Record 6 of Set 3 | esperance
# Processing Record 7 of Set 3 | juneau
# Processing Record 8 of Set 3 | zunyi
# Processing Record 9 of Set 3 | new norfolk
# Processing Record 10 of Set 3 | pali
# Processing Record 11 of Set 3 | cabo san lucas
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | luderitz
# Processing Record 15 of Set 3 | jacareacanga
# Processing Record 16 of Set 3 | kahului
# Processing Record 17 of Set 3 | korla
# Processing Record 18 of Set 3 | sidhpura
# Processing Record 19 of Set 3 | saint-pierre
# Processing Record 20 of Set 3 | kokologo
# Processing Record 21 of Set 3 | flin flon
# Processing Record 22 of Set 3 | touros
# Processing Record 23 of Set 3 | bengkulu
# Processing Record 24 of Set 3 | komsomolskiy
# Processing Record 25 of Set 3 | kawambwa
# Processing Record 26 of Set 3 | bathsheba
# Processing Record 27 of Set 3 | takoradi
# Processing Record 28 of Set 3 | ahipara
# Processing Record 29 of Set 3 | brae
# Processing Record 30 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | kristinehamn
# Processing Record 32 of Set 3 | vitimskiy
# City not found. Skipping...
# Processing Record 33 of Set 3 | pemba
# Processing Record 34 of Set 3 | longyearbyen
# Processing Record 35 of Set 3 | pionerskiy
# Processing Record 36 of Set 3 | dauriya
# Processing Record 37 of Set 3 | hasaki
# Processing Record 38 of Set 3 | yellowknife
# Processing Record 39 of Set 3 | polunochnoye
# Processing Record 40 of Set 3 | bay roberts
# Processing Record 41 of Set 3 | tyup
# Processing Record 42 of Set 3 | tuktoyaktuk
# Processing Record 43 of Set 3 | orangeburg
# Processing Record 44 of Set 3 | yuxia
# Processing Record 45 of Set 3 | nacala
# Processing Record 46 of Set 3 | naryan-mar
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | ndioum
# Processing Record 49 of Set 3 | san rafael del sur
# Processing Record 50 of Set 3 | humberto de campos
# Processing Record 1 of Set 4 | husavik
# Processing Record 2 of Set 4 | wiarton
# Processing Record 3 of Set 4 | shiyan
# Processing Record 4 of Set 4 | avarua
# Processing Record 5 of Set 4 | bambous virieux
# Processing Record 6 of Set 4 | clyde river
# Processing Record 7 of Set 4 | borogontsy
# Processing Record 8 of Set 4 | vila franca do campo
# Processing Record 9 of Set 4 | provideniya
# Processing Record 10 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 4 | nampula
# Processing Record 12 of Set 4 | bluff
# Processing Record 13 of Set 4 | faanui
# Processing Record 14 of Set 4 | zyryanka
# Processing Record 15 of Set 4 | meulaboh
# Processing Record 16 of Set 4 | sorland
# Processing Record 17 of Set 4 | fairbanks
# Processing Record 18 of Set 4 | mahon
# Processing Record 19 of Set 4 | batman
# Processing Record 20 of Set 4 | yulara
# Processing Record 21 of Set 4 | tuatapere
# Processing Record 22 of Set 4 | gillette
# Processing Record 23 of Set 4 | lazaro cardenas
# Processing Record 24 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 4 | vila do maio
# Processing Record 26 of Set 4 | lhokseumawe
# Processing Record 27 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 4 | iqaluit
# Processing Record 29 of Set 4 | arcata
# Processing Record 30 of Set 4 | kaitangata
# Processing Record 31 of Set 4 | tasiilaq
# Processing Record 32 of Set 4 | port augusta
# Processing Record 33 of Set 4 | aklavik
# Processing Record 34 of Set 4 | ketchikan
# Processing Record 35 of Set 4 | chuy
# Processing Record 36 of Set 4 | broome
# Processing Record 37 of Set 4 | muli
# Processing Record 38 of Set 4 | maningrida
# Processing Record 39 of Set 4 | shestakovo
# Processing Record 40 of Set 4 | derzhavinsk
# Processing Record 41 of Set 4 | biak
# Processing Record 42 of Set 4 | puerto escondido
# Processing Record 43 of Set 4 | riyadh
# Processing Record 44 of Set 4 | chapais
# Processing Record 45 of Set 4 | paamiut
# Processing Record 46 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 4 | zhigansk
# Processing Record 48 of Set 4 | itabira
# Processing Record 49 of Set 4 | linxia
# Processing Record 50 of Set 4 | alice springs
# Processing Record 1 of Set 5 | bengkalis
# City not found. Skipping...
# Processing Record 2 of Set 5 | saskylakh
# Processing Record 3 of Set 5 | camocim
# Processing Record 4 of Set 5 | tiksi
# Processing Record 5 of Set 5 | ucluelet
# Processing Record 6 of Set 5 | coihaique
# Processing Record 7 of Set 5 | cayenne
# Processing Record 8 of Set 5 | china
# Processing Record 9 of Set 5 | namwala
# Processing Record 10 of Set 5 | celestun
# Processing Record 11 of Set 5 | half moon bay
# Processing Record 12 of Set 5 | namatanai
# Processing Record 13 of Set 5 | douentza
# Processing Record 14 of Set 5 | nashville
# Processing Record 15 of Set 5 | upernavik
# Processing Record 16 of Set 5 | tonota
# Processing Record 17 of Set 5 | nizwa
# Processing Record 18 of Set 5 | nanortalik
# Processing Record 19 of Set 5 | kavieng
# Processing Record 20 of Set 5 | bud
# Processing Record 21 of Set 5 | pinotepa nacional
# Processing Record 22 of Set 5 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 23 of Set 5 | airai
# Processing Record 24 of Set 5 | talnakh
# Processing Record 25 of Set 5 | lander
# Processing Record 26 of Set 5 | burnie
# Processing Record 27 of Set 5 | te anau
# Processing Record 28 of Set 5 | mehtar lam
# Processing Record 29 of Set 5 | la chapelle-sur-erdre
# Processing Record 30 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 5 | cam pha
# City not found. Skipping...
# Processing Record 32 of Set 5 | kieta
# Processing Record 33 of Set 5 | el alto
# Processing Record 34 of Set 5 | valparaiso
# Processing Record 35 of Set 5 | wanning
# Processing Record 36 of Set 5 | kulhudhuffushi
# Processing Record 37 of Set 5 | lavrentiya
# Processing Record 38 of Set 5 | iquitos
# Processing Record 39 of Set 5 | muros
# Processing Record 40 of Set 5 | henties bay
# Processing Record 41 of Set 5 | lewisville
# Processing Record 42 of Set 5 | castro
# Processing Record 43 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 5 | rancho palos verdes
# Processing Record 45 of Set 5 | koygorodok
# Processing Record 46 of Set 5 | lethem
# Processing Record 47 of Set 5 | los llanos de aridane
# Processing Record 48 of Set 5 | sao joao da barra
# Processing Record 49 of Set 5 | piedras negras
# Processing Record 50 of Set 5 | santo antonio do ica
# Processing Record 1 of Set 6 | clearwater
# Processing Record 2 of Set 6 | vestmannaeyjar
# Processing Record 3 of Set 6 | san patricio
# Processing Record 4 of Set 6 | ancud
# Processing Record 5 of Set 6 | grand gaube
# Processing Record 6 of Set 6 | kuah
# Processing Record 7 of Set 6 | tongliao
# Processing Record 8 of Set 6 | christchurch
# Processing Record 9 of Set 6 | golden
# Processing Record 10 of Set 6 | redlands
# Processing Record 11 of Set 6 | vauvert
# Processing Record 12 of Set 6 | mar del plata
# Processing Record 13 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 6 | tibati
# Processing Record 16 of Set 6 | bowen
# Processing Record 17 of Set 6 | avera
# Processing Record 18 of Set 6 | huarmey
# Processing Record 19 of Set 6 | coruripe
# Processing Record 20 of Set 6 | norman wells
# Processing Record 21 of Set 6 | montauban
# Processing Record 22 of Set 6 | moussoro
# Processing Record 23 of Set 6 | katsuura
# Processing Record 24 of Set 6 | victor harbor
# Processing Record 25 of Set 6 | birin
# Processing Record 26 of Set 6 | oum hadjer
# Processing Record 27 of Set 6 | bisho
# Processing Record 28 of Set 6 | konin
# Processing Record 29 of Set 6 | salalah
# Processing Record 30 of Set 6 | oskaloosa
# Processing Record 31 of Set 6 | nelson bay
# Processing Record 32 of Set 6 | sitka
# Processing Record 33 of Set 6 | kurilsk
# Processing Record 34 of Set 6 | kloulklubed
# Processing Record 35 of Set 6 | kansanshi
# Processing Record 36 of Set 6 | havre-saint-pierre
# Processing Record 37 of Set 6 | lagoa
# Processing Record 38 of Set 6 | pisco
# Processing Record 39 of Set 6 | saint anthony
# Processing Record 40 of Set 6 | minab
# Processing Record 41 of Set 6 | umm bab
# Processing Record 42 of Set 6 | deputatskiy
# Processing Record 43 of Set 6 | san cristobal
# Processing Record 44 of Set 6 | panguna
# Processing Record 45 of Set 6 | port blair
# Processing Record 46 of Set 6 | holbeach
# Processing Record 47 of Set 6 | keti bandar
# Processing Record 48 of Set 6 | luanda
# Processing Record 49 of Set 6 | shingu
# Processing Record 50 of Set 6 | noicattaro
# Processing Record 1 of Set 7 | uige
# Processing Record 2 of Set 7 | faya
# Processing Record 3 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 7 | port hedland
# Processing Record 5 of Set 7 | zhifang
# Processing Record 6 of Set 7 | beihai
# Processing Record 7 of Set 7 | shubarshi
# Processing Record 8 of Set 7 | mezen
# Processing Record 9 of Set 7 | eydhafushi
# Processing Record 10 of Set 7 | port lincoln
# Processing Record 11 of Set 7 | sambava
# Processing Record 12 of Set 7 | maceio
# Processing Record 13 of Set 7 | fairlie
# Processing Record 14 of Set 7 | manokwari
# Processing Record 15 of Set 7 | kasangulu
# Processing Record 16 of Set 7 | cherskiy
# Processing Record 17 of Set 7 | kapoeta
# Processing Record 18 of Set 7 | mareeba
# Processing Record 19 of Set 7 | atambua
# Processing Record 20 of Set 7 | te karaka
# Processing Record 21 of Set 7 | leh
# Processing Record 22 of Set 7 | inongo
# Processing Record 23 of Set 7 | port hardy
# Processing Record 24 of Set 7 | moree
# Processing Record 25 of Set 7 | eyl
# Processing Record 26 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 7 | mbini
# Processing Record 28 of Set 7 | suao
# City not found. Skipping...
# Processing Record 29 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 7 | north bend
# Processing Record 31 of Set 7 | east london
# Processing Record 32 of Set 7 | honningsvag
# Processing Record 33 of Set 7 | altzayanca
# Processing Record 34 of Set 7 | labuhan
# Processing Record 35 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 7 | nha trang
# Processing Record 37 of Set 7 | sovetskiy
# Processing Record 38 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 7 | pacifica
# Processing Record 40 of Set 7 | anadyr
# Processing Record 41 of Set 7 | lebu
# Processing Record 42 of Set 7 | payo
# Processing Record 43 of Set 7 | raudeberg
# Processing Record 44 of Set 7 | nhamunda
# Processing Record 45 of Set 7 | kpandu
# Processing Record 46 of Set 7 | laguna
# Processing Record 47 of Set 7 | burns lake
# Processing Record 48 of Set 7 | suluq
# Processing Record 49 of Set 7 | iranshahr
# Processing Record 50 of Set 7 | prince george
# Processing Record 1 of Set 8 | isangel
# Processing Record 2 of Set 8 | lodja
# Processing Record 3 of Set 8 | kumylzhenskaya
# Processing Record 4 of Set 8 | olafsvik
# Processing Record 5 of Set 8 | nishihara
# Processing Record 6 of Set 8 | margate
# Processing Record 7 of Set 8 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 8 of Set 8 | kindersley
# Processing Record 9 of Set 8 | mantua
# Processing Record 10 of Set 8 | sorong
# Processing Record 11 of Set 8 | brownsville
# Processing Record 12 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 8 | itoman
# Processing Record 14 of Set 8 | chambas
# Processing Record 15 of Set 8 | south river
# Processing Record 16 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 17 of Set 8 | shaunavon
# Processing Record 18 of Set 8 | diego de almagro
# Processing Record 19 of Set 8 | antofagasta
# Processing Record 20 of Set 8 | constitucion
# Processing Record 21 of Set 8 | gravatai
# Processing Record 22 of Set 8 | awjilah
# Processing Record 23 of Set 8 | duxbury
# Processing Record 24 of Set 8 | colares
# Processing Record 25 of Set 8 | ostrovnoy
# Processing Record 26 of Set 8 | chhatak
# Processing Record 27 of Set 8 | bako
# Processing Record 28 of Set 8 | flinders
# Processing Record 29 of Set 8 | beipiao
# Processing Record 30 of Set 8 | saint george
# Processing Record 31 of Set 8 | walvis bay
# Processing Record 32 of Set 8 | bilibino
# Processing Record 33 of Set 8 | kavaratti
# Processing Record 34 of Set 8 | aripuana
# Processing Record 35 of Set 8 | lagos
# Processing Record 36 of Set 8 | victoria
# Processing Record 37 of Set 8 | kidal
# Processing Record 38 of Set 8 | gunnedah
# Processing Record 39 of Set 8 | ginir
# Processing Record 40 of Set 8 | sibolga
# Processing Record 41 of Set 8 | hofn
# Processing Record 42 of Set 8 | abu dhabi
# Processing Record 43 of Set 8 | sao filipe
# Processing Record 44 of Set 8 | codrington
# Processing Record 45 of Set 8 | ntungamo
# Processing Record 46 of Set 8 | plaeng yao
# Processing Record 47 of Set 8 | srandakan
# Processing Record 48 of Set 8 | westport
# Processing Record 49 of Set 8 | itaiba
# Processing Record 50 of Set 8 | ous
# Processing Record 1 of Set 9 | cockburn town
# Processing Record 2 of Set 9 | adrar
# Processing Record 3 of Set 9 | san jose de guanipa
# Processing Record 4 of Set 9 | seymchan
# Processing Record 5 of Set 9 | makaha
# Processing Record 6 of Set 9 | esil
# Processing Record 7 of Set 9 | murray bridge
# Processing Record 8 of Set 9 | erzin
# Processing Record 9 of Set 9 | falmouth
# Processing Record 10 of Set 9 | caravelas
# Processing Record 11 of Set 9 | fortuna
# Processing Record 12 of Set 9 | bakal
# Processing Record 13 of Set 9 | nichinan
# Processing Record 14 of Set 9 | kalabo
# Processing Record 15 of Set 9 | nicolet
# Processing Record 16 of Set 9 | juegang
# Processing Record 17 of Set 9 | oranjemund
# Processing Record 18 of Set 9 | toba
# Processing Record 19 of Set 9 | morden
# Processing Record 20 of Set 9 | zhirnovsk
# Processing Record 21 of Set 9 | makakilo city
# Processing Record 22 of Set 9 | yanam
# Processing Record 23 of Set 9 | pangai
# Processing Record 24 of Set 9 | gawler
# Processing Record 25 of Set 9 | rioja
# Processing Record 26 of Set 9 | rongcheng
# Processing Record 27 of Set 9 | fengrun
# Processing Record 28 of Set 9 | krasnoselkup
# Processing Record 29 of Set 9 | gopalpur
# Processing Record 30 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 9 | kracheh
# City not found. Skipping...
# Processing Record 32 of Set 9 | guerrero negro
# Processing Record 33 of Set 9 | sal rei
# Processing Record 34 of Set 9 | marinette
# Processing Record 35 of Set 9 | hami
# Processing Record 36 of Set 9 | leningradskiy
# Processing Record 37 of Set 9 | ambilobe
# Processing Record 38 of Set 9 | terrace bay
# Processing Record 39 of Set 9 | kyshtovka
# Processing Record 40 of Set 9 | mersing
# Processing Record 41 of Set 9 | vardo
# Processing Record 42 of Set 9 | kimbe
# Processing Record 43 of Set 9 | ekhabi
# Processing Record 44 of Set 9 | listvyanskiy
# Processing Record 45 of Set 9 | bereslavka
# Processing Record 46 of Set 9 | neiafu
# Processing Record 47 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 9 | duz
# City not found. Skipping...
# Processing Record 49 of Set 9 | acapulco
# Processing Record 50 of Set 9 | marsh harbour
# Processing Record 1 of Set 10 | nerja
# Processing Record 2 of Set 10 | itauna
# Processing Record 3 of Set 10 | shirokiy
# Processing Record 4 of Set 10 | vila
# Processing Record 5 of Set 10 | lincoln
# Processing Record 6 of Set 10 | vavuniya
# Processing Record 7 of Set 10 | ouango
# Processing Record 8 of Set 10 | gazojak
# Processing Record 9 of Set 10 | san quintin
# Processing Record 10 of Set 10 | beboto
# Processing Record 11 of Set 10 | lebyazhye
# Processing Record 12 of Set 10 | taunggyi
# Processing Record 13 of Set 10 | narsaq
# Processing Record 14 of Set 10 | abasha
# Processing Record 15 of Set 10 | khvastovichi
# Processing Record 16 of Set 10 | onega
# Processing Record 17 of Set 10 | magistralnyy
# Processing Record 18 of Set 10 | knokke-heist
# Processing Record 19 of Set 10 | cabedelo
# Processing Record 20 of Set 10 | lixourion
# Processing Record 21 of Set 10 | shorkot
# Processing Record 22 of Set 10 | nhulunbuy
# Processing Record 23 of Set 10 | barentu
# Processing Record 24 of Set 10 | severo-kurilsk
# Processing Record 25 of Set 10 | nigde
# Processing Record 26 of Set 10 | fernie
# Processing Record 27 of Set 10 | tateyama
# Processing Record 28 of Set 10 | kruisfontein
# Processing Record 29 of Set 10 | dingle
# Processing Record 30 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 10 | iwanai
# Processing Record 32 of Set 10 | tefe
# Processing Record 33 of Set 10 | camacha
# Processing Record 34 of Set 10 | nipawin
# Processing Record 35 of Set 10 | linjiang
# Processing Record 36 of Set 10 | vao
# Processing Record 37 of Set 10 | calmar
# Processing Record 38 of Set 10 | malinovskiy
# Processing Record 39 of Set 10 | batagay-alyta
# Processing Record 40 of Set 10 | tibiri
# Processing Record 41 of Set 10 | tokmak
# Processing Record 42 of Set 10 | nosy varika
# Processing Record 43 of Set 10 | japura
# Processing Record 44 of Set 10 | port-gentil
# Processing Record 45 of Set 10 | tornio
# Processing Record 46 of Set 10 | mehamn
# Processing Record 47 of Set 10 | vila velha
# Processing Record 48 of Set 10 | contamana
# Processing Record 49 of Set 10 | tura
# Processing Record 50 of Set 10 | astana
# Processing Record 1 of Set 11 | jiayuguan
# Processing Record 2 of Set 11 | puksoozero
# Processing Record 3 of Set 11 | mogadishu
# Processing Record 4 of Set 11 | thinadhoo
# Processing Record 5 of Set 11 | petatlan
# Processing Record 6 of Set 11 | dimbokro
# Processing Record 7 of Set 11 | beloha
# Processing Record 8 of Set 11 | ust-ishim
# Processing Record 9 of Set 11 | berlevag
# Processing Record 10 of Set 11 | nome
# Processing Record 11 of Set 11 | kharp
# Processing Record 12 of Set 11 | kargasok
# Processing Record 13 of Set 11 | ndele
# Processing Record 14 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 15 of Set 11 | hobyo
# Processing Record 16 of Set 11 | alugan
# Processing Record 17 of Set 11 | esso
# Processing Record 18 of Set 11 | pyapon
# Processing Record 19 of Set 11 | muyezerskiy
# Processing Record 20 of Set 11 | port hawkesbury
# Processing Record 21 of Set 11 | myrtle beach
# Processing Record 22 of Set 11 | alofi
# Processing Record 23 of Set 11 | barabai
# Processing Record 24 of Set 11 | manta
# Processing Record 25 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 11 | champerico
# Processing Record 27 of Set 11 | vega de alatorre
# Processing Record 28 of Set 11 | vikhorevka
# Processing Record 29 of Set 11 | severnyy-kospashskiy
# Processing Record 30 of Set 11 | mao
# Processing Record 31 of Set 11 | mount gambier
# Processing Record 32 of Set 11 | khonsa
# Processing Record 33 of Set 11 | karonga
# Processing Record 34 of Set 11 | torbay
# Processing Record 35 of Set 11 | xichang
# Processing Record 36 of Set 11 | kantemirovka
# Processing Record 37 of Set 11 | rocha
# Processing Record 38 of Set 11 | morehead
# Processing Record 39 of Set 11 | sherwood
# Processing Record 40 of Set 11 | murgab
# Processing Record 41 of Set 11 | semnan
# Processing Record 42 of Set 11 | goundam
# Processing Record 43 of Set 11 | oktyabrskiy
# Processing Record 44 of Set 11 | kalanguy
# Processing Record 45 of Set 11 | high level
# Processing Record 46 of Set 11 | barquisimeto
# Processing Record 47 of Set 11 | gaozhou
# Processing Record 48 of Set 11 | udachnyy
# Processing Record 49 of Set 11 | turukhansk
# Processing Record 50 of Set 11 | ottawa
# Processing Record 1 of Set 12 | kota belud
# Processing Record 2 of Set 12 | jeremie
# Processing Record 3 of Set 12 | omboue
# Processing Record 4 of Set 12 | byron bay
# Processing Record 5 of Set 12 | martinopolis
# Processing Record 6 of Set 12 | sri aman
# Processing Record 7 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 12 | zavetnoye
# Processing Record 9 of Set 12 | jaguaribe
# Processing Record 10 of Set 12 | bubaque
# Processing Record 11 of Set 12 | auki
# Processing Record 12 of Set 12 | williams lake
# Processing Record 13 of Set 12 | kalianget
# Processing Record 14 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 15 of Set 12 | asau
# Processing Record 16 of Set 12 | tilichiki
# Processing Record 17 of Set 12 | fuyang
# Processing Record 18 of Set 12 | abu samrah
# Processing Record 19 of Set 12 | batemans bay
# Processing Record 20 of Set 12 | impfondo
# Processing Record 21 of Set 12 | gotemba
# Processing Record 22 of Set 12 | abalak
# Processing Record 23 of Set 12 | palauig
# Processing Record 24 of Set 12 | myitkyina
# Processing Record 25 of Set 12 | roma
# Processing Record 26 of Set 12 | clinton
# Processing Record 27 of Set 12 | kosonsoy
# Processing Record 28 of Set 12 | neuquen
# Processing Record 29 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 12 | pitsunda
# Processing Record 31 of Set 12 | narasannapeta
# Processing Record 32 of Set 12 | mahebourg
# Processing Record 33 of Set 12 | bilma
# Processing Record 34 of Set 12 | santiago
# Processing Record 35 of Set 12 | tautira
# Processing Record 36 of Set 12 | coria
# Processing Record 37 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 38 of Set 12 | benguela
# Processing Record 39 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 41 of Set 12 | sumbe
# Processing Record 42 of Set 12 | yeroham
# Processing Record 43 of Set 12 | batsfjord
# Processing Record 44 of Set 12 | orlik
# Processing Record 45 of Set 12 | tabas
# Processing Record 46 of Set 12 | cap-aux-meules
# Processing Record 47 of Set 12 | sioux lookout
# Processing Record 48 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 49 of Set 12 | zarichne
# Processing Record 50 of Set 12 | kupang
# Processing Record 1 of Set 13 | alekseyevsk
# Processing Record 2 of Set 13 | gorontalo
# Processing Record 3 of Set 13 | kysyl-syr
# Processing Record 4 of Set 13 | springfield
# Processing Record 5 of Set 13 | quatre cocos
# Processing Record 6 of Set 13 | kayseri
# Processing Record 7 of Set 13 | hambantota
# Processing Record 8 of Set 13 | twentynine palms
# Processing Record 9 of Set 13 | paranhos
# Processing Record 10 of Set 13 | olavarria
# Processing Record 11 of Set 13 | the valley
# Processing Record 12 of Set 13 | tessalit
# Processing Record 13 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 14 of Set 13 | teknaf
# Processing Record 15 of Set 13 | kijang
# Processing Record 16 of Set 13 | nardaran
# Processing Record 17 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 18 of Set 13 | pangody
# Processing Record 19 of Set 13 | den helder
# Processing Record 20 of Set 13 | terney
# Processing Record 21 of Set 13 | methoni
# Processing Record 22 of Set 13 | dabat
# Processing Record 23 of Set 13 | comodoro rivadavia
# Processing Record 24 of Set 13 | pucallpa
# Processing Record 25 of Set 13 | changli
# Processing Record 26 of Set 13 | banda aceh
# Processing Record 27 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 28 of Set 13 | macusani
# Processing Record 29 of Set 13 | manakara
# Processing Record 30 of Set 13 | fukue
# Processing Record 31 of Set 13 | stornoway
# Processing Record 32 of Set 13 | kihei
# Processing Record 33 of Set 13 | aswan
# Processing Record 34 of Set 13 | sisimiut
# Processing Record 35 of Set 13 | kharitonovo
# Processing Record 36 of Set 13 | xingyi
# Processing Record 37 of Set 13 | qinhuangdao
# Processing Record 38 of Set 13 | lasa
# Processing Record 39 of Set 13 | moose factory
# Processing Record 40 of Set 13 | portland
# Processing Record 41 of Set 13 | sao felix do xingu
# Processing Record 42 of Set 13 | rapar
# Processing Record 43 of Set 13 | corn island
# Processing Record 44 of Set 13 | aguadilla
# Processing Record 45 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 13 | salaga
# Processing Record 47 of Set 13 | sao jose da coroa grande
# Processing Record 48 of Set 13 | mildura
# Processing Record 49 of Set 13 | lianzhou
# Processing Record 50 of Set 13 | badhni kalan
# Processing Record 1 of Set 14 | galle
# Processing Record 2 of Set 14 | pochutla
# Processing Record 3 of Set 14 | paraguacu
# Processing Record 4 of Set 14 | coolum beach
# Processing Record 5 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 6 of Set 14 | chabahar
# Processing Record 7 of Set 14 | hay river
# Processing Record 8 of Set 14 | taitung
# Processing Record 9 of Set 14 | nantucket
# Processing Record 10 of Set 14 | uray
# Processing Record 11 of Set 14 | ryazanovskiy
# Processing Record 12 of Set 14 | san buenaventura
# Processing Record 13 of Set 14 | cassilandia
# Processing Record 14 of Set 14 | solnechnyy
# Processing Record 15 of Set 14 | wahpeton
# Processing Record 16 of Set 14 | diffa
# Processing Record 17 of Set 14 | jiaozuo
# Processing Record 18 of Set 14 | cervo
# Processing Record 19 of Set 14 | sao jose do egito
# Processing Record 20 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 14 | jumla
# Processing Record 22 of Set 14 | cuencame
# Processing Record 23 of Set 14 | ayat
# Processing Record 24 of Set 14 | palmer
# Processing Record 25 of Set 14 | west bay
# Processing Record 26 of Set 14 | kemijarvi
# Processing Record 27 of Set 14 | matara
# Processing Record 28 of Set 14 | bairiki
# Processing Record 29 of Set 14 | turayf
# Processing Record 30 of Set 14 | gayny
# Processing Record 31 of Set 14 | tanete
# Processing Record 32 of Set 14 | micheweni
# Processing Record 33 of Set 14 | port moresby
# Processing Record 34 of Set 14 | qidong
# Processing Record 35 of Set 14 | kolo
# Processing Record 36 of Set 14 | srednekolymsk
# Processing Record 37 of Set 14 | bhimunipatnam
# Processing Record 38 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 14 | chadan
# Processing Record 40 of Set 14 | kaeo
# Processing Record 41 of Set 14 | mormugao
# Processing Record 42 of Set 14 | nombre de dios
# Processing Record 43 of Set 14 | san andres
# Processing Record 44 of Set 14 | atarfe
# Processing Record 45 of Set 14 | bambanglipuro
# Processing Record 46 of Set 14 | matamoros
# Processing Record 47 of Set 14 | strezhevoy
# Processing Record 48 of Set 14 | canutama
# Processing Record 49 of Set 14 | aksay
# Processing Record 50 of Set 14 | yuncheng
# Processing Record 1 of Set 15 | havoysund
# Processing Record 2 of Set 15 | gourbeyre
# Processing Record 3 of Set 15 | baykit
# Processing Record 4 of Set 15 | beringovskiy
# Processing Record 5 of Set 15 | almenevo
# City not found. Skipping...
# Processing Record 6 of Set 15 | atherton
# Processing Record 7 of Set 15 | morondava
# Processing Record 8 of Set 15 | yaan
# Processing Record 9 of Set 15 | prince rupert
# Processing Record 10 of Set 15 | mehran
# Processing Record 11 of Set 15 | manicore
# Processing Record 12 of Set 15 | darnah
# Processing Record 13 of Set 15 | verkhnevilyuysk
# Processing Record 14 of Set 15 | aksarka
# Processing Record 15 of Set 15 | khandyga
# Processing Record 16 of Set 15 | voznesenye
# Processing Record 17 of Set 15 | harper
# Processing Record 18 of Set 15 | burgersdorp
# Processing Record 19 of Set 15 | kurchum
# Processing Record 20 of Set 15 | xining
# Processing Record 21 of Set 15 | tual
# Processing Record 22 of Set 15 | new london
# Processing Record 23 of Set 15 | krasnoturinsk
# Processing Record 24 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 15 | yarmouth
# Processing Record 26 of Set 15 | punta cardon
# Processing Record 27 of Set 15 | keshod
# Processing Record 28 of Set 15 | kinanah
# City not found. Skipping...
# Processing Record 29 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 15 | abrau-dyurso
# Processing Record 31 of Set 15 | senneterre
# Processing Record 32 of Set 15 | monroe
# Processing Record 33 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 34 of Set 15 | kismayo
# Processing Record 35 of Set 15 | malpe
# Processing Record 36 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 15 | bukachacha
# Processing Record 38 of Set 15 | roald
# Processing Record 39 of Set 15 | llanes
# Processing Record 40 of Set 15 | novo aripuana
# Processing Record 41 of Set 15 | bealanana
# Processing Record 42 of Set 15 | kahta
# Processing Record 43 of Set 15 | sandakan
# Processing Record 44 of Set 15 | mbigou
# Processing Record 45 of Set 15 | nabire
# Processing Record 46 of Set 15 | qaqortoq
# Processing Record 47 of Set 15 | naze
# Processing Record 48 of Set 15 | carutapera
# Processing Record 49 of Set 15 | lengshuitan
# Processing Record 50 of Set 15 | broken hill
# Processing Record 1 of Set 16 | syedove
# Processing Record 2 of Set 16 | loiza
# Processing Record 3 of Set 16 | saint-honore
# Processing Record 4 of Set 16 | belmopan
# Processing Record 5 of Set 16 | shagonar
# Processing Record 6 of Set 16 | kudahuvadhoo
# Processing Record 7 of Set 16 | weatherford
# Processing Record 8 of Set 16 | velky osek
# Processing Record 9 of Set 16 | aktau
# Processing Record 10 of Set 16 | college station
# Processing Record 11 of Set 16 | progreso
# Processing Record 12 of Set 16 | nyagan
# Processing Record 13 of Set 16 | koltubanovskiy
# Processing Record 14 of Set 16 | santa isabel do rio negro
# Processing Record 15 of Set 16 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 16 | raga
# Processing Record 17 of Set 16 | estelle
# Processing Record 18 of Set 16 | hovd
# Processing Record 19 of Set 16 | sakakah
# Processing Record 20 of Set 16 | kristianstad
# Processing Record 21 of Set 16 | yatou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Kapaa      US  22.08 -159.32     82.99        65          90
# 1       Colac      AU -38.33  143.58     57.00        77          94
# 2     Rikitea      PF -23.12 -134.97     75.83        67           0
# 3     Samarai      PG -10.62  150.67     81.99        80         100
# 4  Georgetown      MY   5.41  100.34     77.00        94          20
# 5     Birjand      IR  32.87   59.22     35.60         8           0
# 6      Tutoia      BR  -2.76  -42.27     80.98        80          47
# 7      Atuona      PF  -9.80 -139.03     78.44        75          11
# 8        Sola      VU -13.88  167.55     81.55        80          67
# 9   Ilulissat      GL  69.22  -51.10     21.20        73         100
#
#    Wind Speed Current Description
# 0       13.87     overcast clouds
# 1        3.71     overcast clouds
# 2        5.86           clear sky
# 3        8.30          light rain
# 4        3.36          few clouds
# 5        4.70           clear sky
# 6       13.29    scattered clouds
# 7       17.63          few clouds
# 8       19.33       broken clouds
# 9       10.29   light shower snow

# %%
file_store = '/Users/replate-blueberry/Desktop/Data Analysis/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv'
city_data_df.to_csv(file_store, index_label="City_ID")
